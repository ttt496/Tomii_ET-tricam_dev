# %%
# %cd /content/Tomii_ET-tricam_dev
# %pip install -r requirements-colab.txt  # 依存だけ入れる（pyprojectの難しい条件を避ける）

import sys
sys.path.append("/content/Tomii_ET-tricam_dev")  # <- これで data_process.araya_eye を解決

import os
import eye_crop_pipeline
import cv2
import numpy as np
import pathlib
# Out:
# /content/Tomii_ET-tricam_dev
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements-colab.txt'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2492292345.py in <cell line: 0>()
#       6
#       7 import os
# ----> 8 import eye_crop_pipeline
#       9 import cv2
#      10 import numpy as np
#
# /content/Tomii_ET-tricam_dev/eye_crop_pipeline.py in <module>
#       4 from pathlib import Path
#       5
# ----> 6 from data_process.sync_inference import run_sync_and_extract_eyes
#       7
#       8
#
# /content/Tomii_ET-tricam_dev/data_process/sync_inference.py in <module>
#      20     synchronize_session,
#      21 )
# ---> 22 from data_process.araya_eye.core.dtypes.media import ImageArray
#      23 from data_process.araya_eye.core.integrators.blink_detector.api import EARBlinkDetails
#      24 from data_process.araya_eye.core.integrators.face_detector.wrappers.yolov9_wb25.config import (
#
# ModuleNotFoundError: No module named 'data_process.araya_eye'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/Tomii_ET-tricam_dev
# !ls
# !pwd
# Out:
# /content/Tomii_ET-tricam_dev
# araya_eye	      main.py	      recording		 training
# data		      __pycache__     snapshots		 ui_mock.py
# data_process	      pyproject.toml  tomii_et.egg-info
# eye_crop_pipeline.py  README.md       tools
# /content/Tomii_ET-tricam_dev
